# %%
                       Working on Real Project with python
                       (A part of big data analysis)

# %%
Electoral Bond Data - State Bank of India
Public disclosure of Electoral Bond data uploaded by ECI

The Election Commission has published details of the electoral bond data recevied from the State Bank of India (SBI) on its website.

According to the Election Commission, the data has been shared in two parts. 
The first set of data shows the name of the purchaser and denomination of the bonds while the other shows the political parties and 
denomination of the bonds encashed by them. Both of the files are attached below.

# %% [markdown]
#   The Electrol Bond Dataset ECI
#                         Electrol bond dataset from https://www.eci.gov.in/disclosure-of-electoral-bonds
#                         converted into xlsx as well as csv format.
#                         Contain these two files:
#
#
#                         Details of Electoral Bonds submitted by SBI Part -II
#                         Date: 14 Mar 2024 Thursday, 7:55 PM
#
#
#                         Details of Electoral Bonds submitted by SBI Part -I
#                         Date: 14 Mar 2024 Thursday ,7:53 PM

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Arya\anaconda3\envs\4Ass3J1tc8.csv")
data1 = pd.read_csv(r"C:\Users\Arya\anaconda3\envs\zgrupcD1UJ.csv")

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
data
# Out:
#       Date of Purchase                  Purchaser Name Denomination
# 0          12/Apr/2019             A B C INDIA LIMITED     1,00,000
# 1          12/Apr/2019             A B C INDIA LIMITED     1,00,000
# 2          12/Apr/2019             A B C INDIA LIMITED    10,00,000
# 3          12/Apr/2019             A B C INDIA LIMITED    10,00,000
# 4          12/Apr/2019             A B C INDIA LIMITED     1,00,000
# ...                ...                             ...          ...
# 18866      11/Jan/2024  WESTWELL GASES PRIVATE LIMITED  1,00,00,000
# 18867      11/Jan/2024  WESTWELL GASES PRIVATE LIMITED  1,00,00,000
# 18868      11/Jan/2024  WESTWELL GASES PRIVATE LIMITED  1,00,00,000
# 18869      11/Jan/2024  WESTWELL GASES PRIVATE LIMITED  1,00,00,000
# 18870      11/Jan/2024  WESTWELL GASES PRIVATE LIMITED  1,00,00,000
#
# [18871 rows x 3 columns]

# %%
output1= pd.merge(data,data1,on='Denomination',how='inner')

# %%
output1
# Out:
#           Date of Purchase                      Purchaser Name Denomination  \
# 0              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 1              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 2              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 3              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 4              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# ...                    ...                                 ...          ...
# 172948516      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948517      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948518      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948519      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948520      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
#
# ...

# %% [markdown]
# HOW TO ANALYSE DATA FRAMES ?
#  1.  .head()
#       = It shows the first N rows in the data (by default N = 5)

# %%
output1.head()
# Out:
#   Date of Purchase       Purchaser Name Denomination Date of\nEncashment  \
# 0      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 1      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 2      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 3      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 4      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
#
#   Name of the Political Party
# 0        BHARTIYA JANTA PARTY
# 1        BHARTIYA JANTA PARTY
# 2        BHARTIYA JANTA PARTY
# 3        BHARTIYA JANTA PARTY
# 4        BHARTIYA JANTA PARTY

# %%
2.    .shape
    = It shows thr total no. of rows and no. of columns of the dataframe.

# %%
output1.shape
# Out:
# (172948521, 5)

# %%
3.      .index
        = The attribute provides the index of the dataframe.

# %%
output1.index
# Out:
# RangeIndex(start=0, stop=172948521, step=1)

# %%
4.       .columns
        = It shows the name  of each column

# %%
output1.columns
# Out:
# Index(['Date of Purchase', 'Purchaser Name', 'Denomination',
#        'Date of\nEncashment', 'Name of the Political Party'],
#       dtype='object')

# %%
5.         .dtypes
           = Itshows the data type of each column

# %%
output1.dtypes
# Out:
# Date of Purchase               object
# Purchaser Name                 object
# Denomination                   object
# Date of\nEncashment            object
# Name of the Political Party    object
# dtype: object

# %%
6.             .unique()
          = In a column it shows a unique value , it can be applied to a single column only , not on the whole data frame.

# %%
output1['Name of the Political Party'].unique()
# Out:
# array(['BHARTIYA JANTA PARTY', 'YSR CONGRESS PARTY (YUVAJANA SRAMIKA R',
#        'ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM',
#        'PRESIDENT, ALL INDIA CONGRESS COMMITTEE',
#        'ALL INDIA TRINAMOOL CONGRESS', 'ADYAKSHA SAMAJVADI PARTY',
#        'BHARAT RASHTRA SAMITHI', 'SHIROMANI AKALI DAL',
#        'SHIVSENA (POLITICAL PARTY)',
#        'NATIONALIST CONGRESS PARTY PARLIAMENT OF', 'AAM AADMI PARTY',
#        'GOA FORWARD PARTY', 'MAHARASHTRAWADI GOMNTAK PARTY',
#        'JHARKHAND MUKTI MORCHA', 'TELUGU DESAM PARTY',
#        'RASTRIYA JANTA DAL', 'JANATA DAL ( SECULAR )',
#        'JAMMU AND KASHMIR NATIONAL CONFERENCE',
#        'NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH',
#        'BIJU JANATA DAL', 'DMK PARTY IN PARLIAMENT',
#        'SIKKIM KRANTIKARI MORCHA', 'SIKKIM DEMOCRATIC FRONT',
#        'JANASENA PARTY', 'BIHAR PRADESH JANTA DAL(UNITED)', 'SHIVSENA',
#        'RASHTRIYA JANTA DAL'], dtype=object)

# %%
7.         .nunique()
           =It shows the total number of unique values in each column .It cab be applied on a single column as well as whole datatframe.

# %%
output1.nunique()
# Out:
# Date of Purchase                146
# Purchaser Name                 1320
# Denomination                      5
# Date of\nEncashment             230
# Name of the Political Party      27
# dtype: int64

# %%
8.            .count
          = It shows th total number of not null values in each column . It can be applied on a single column as well as whole data frame.

# %%
output1.count
# Out:
# <bound method DataFrame.count of           Date of Purchase                      Purchaser Name Denomination  \
# 0              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 1              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 2              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 3              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 4              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# ...                    ...                                 ...          ...
# 172948516      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948517      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948518      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948519      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948520      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
#
# ...

# %%
9.              value_counts()
                = In a column .It shows all the unique values with their count .It can be applied on single column only.

# %%
output1['Purchaser Name'].value_counts()
# Out:
# Purchaser Name
# FUTURE GAMING AND HOTEL SERVICES PR               14746056
# MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED    10021947
# QWIKSUPPLYCHAINPRIVATELIMITED                      5004870
# HALDIA ENERGY LIMITED                              4684945
# VEDANTA LIMITED                                    4622451
#                                                     ...
# DAMINI NATH                                            103
# PAWAN AGARWAL                                          103
# ADWITA FINVEST PRIVATE LIMITED                         103
# POONAM AGARWAL                                         103
# N RAMAMOORTHY                                          103
# Name: count, Length: 1320, dtype: int64

# %%
10.                   info()
                     = Provides basic information about the dataframe.

# %%
output1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172948521 entries, 0 to 172948520
# Data columns (total 5 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Date of Purchase             object
#  1   Purchaser Name               object
#  2   Denomination                 object
#  3   Date of
# Encashment           object
#  4   Name of the Political Party  object
# dtypes: object(5)
# memory usage: 6.4+ GB

# %%
#  OBJECTIVES

# %%
# 1.Find all the unique political parties in the data.

# %%
output1.head(10)
# Out:
#   Date of Purchase       Purchaser Name Denomination Date of\nEncashment  \
# 0      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 1      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 2      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 3      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 4      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 5      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 6      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 7      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 8      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 9      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
#
#   Name of the Political Party
# 0        BHARTIYA JANTA PARTY
# 1        BHARTIYA JANTA PARTY
# 2        BHARTIYA JANTA PARTY
# 3        BHARTIYA JANTA PARTY
# ...

# %%
output1.nunique()
# Out:
# Date of Purchase                146
# Purchaser Name                 1320
# Denomination                      5
# Date of\nEncashment             230
# Name of the Political Party      27
# dtype: int64

# %%
output1['Name of the Political Party'].nunique()
# Out:
# 27

# %%
output1['Name of the Political Party'].unique()
# Out:
# array(['BHARTIYA JANTA PARTY', 'YSR CONGRESS PARTY (YUVAJANA SRAMIKA R',
#        'ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM',
#        'PRESIDENT, ALL INDIA CONGRESS COMMITTEE',
#        'ALL INDIA TRINAMOOL CONGRESS', 'ADYAKSHA SAMAJVADI PARTY',
#        'BHARAT RASHTRA SAMITHI', 'SHIROMANI AKALI DAL',
#        'SHIVSENA (POLITICAL PARTY)',
#        'NATIONALIST CONGRESS PARTY PARLIAMENT OF', 'AAM AADMI PARTY',
#        'GOA FORWARD PARTY', 'MAHARASHTRAWADI GOMNTAK PARTY',
#        'JHARKHAND MUKTI MORCHA', 'TELUGU DESAM PARTY',
#        'RASTRIYA JANTA DAL', 'JANATA DAL ( SECULAR )',
#        'JAMMU AND KASHMIR NATIONAL CONFERENCE',
#        'NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH',
#        'BIJU JANATA DAL', 'DMK PARTY IN PARLIAMENT',
#        'SIKKIM KRANTIKARI MORCHA', 'SIKKIM DEMOCRATIC FRONT',
#        'JANASENA PARTY', 'BIHAR PRADESH JANTA DAL(UNITED)', 'SHIVSENA',
#        'RASHTRIYA JANTA DAL'], dtype=object)

# %%
#2. Find the number of times when the political party is Bhartiya Janta party.

# %%
output1.head(10)
# Out:
#   Date of Purchase       Purchaser Name Denomination Date of\nEncashment  \
# 0      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 1      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 2      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 3      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 4      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 5      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 6      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 7      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 8      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 9      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
#
#   Name of the Political Party
# 0        BHARTIYA JANTA PARTY
# 1        BHARTIYA JANTA PARTY
# 2        BHARTIYA JANTA PARTY
# 3        BHARTIYA JANTA PARTY
# ...

# %%
# value_counts()
output1['Name of the Political Party'].value_counts()
# Out:
# Name of the Political Party
# BHARTIYA JANTA PARTY                              79121934
# ALL INDIA TRINAMOOL CONGRESS                      24437365
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE           21605698
# BHARAT RASHTRA SAMITHI                            15820295
# BIJU JANATA DAL                                    9378886
# DMK PARTY IN PARLIAMENT                            7492298
# YSR CONGRESS PARTY (YUVAJANA SRAMIKA R             4349848
# TELUGU DESAM PARTY                                 2754838
# SHIVSENA (POLITICAL PARTY)                         2245298
# AAM AADMI PARTY                                    1292465
# RASTRIYA JANTA DAL                                 1122775
# NATIONALIST CONGRESS PARTY PARLIAMENT OF            650253
# JANATA DAL ( SECULAR )                              628540
# SIKKIM KRANTIKARI MORCHA                            477785
# JANASENA PARTY                                      314149
# ...

# %%
#Filtering
#output1.head(10)
output1[output1['Name of the Political Party'] == 'BHARTIYA JANTA PARTY']
# Out:
#           Date of Purchase                      Purchaser Name Denomination  \
# 0              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 1              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 2              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 3              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 4              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# ...                    ...                                 ...          ...
# 172948456      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948457      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948458      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948459      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948520      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
#
# ...

# %%
#Grouping
#output1.head(10)
output1.groupby('Name of the Political Party').get_group('BHARTIYA JANTA PARTY')
# Out:
#           Date of Purchase                      Purchaser Name Denomination  \
# 0              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 1              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 2              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 3              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 4              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# ...                    ...                                 ...          ...
# 172948456      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948457      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948458      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948459      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948520      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
#
# ...

# %%
# Find the number of times when Purchaser Name was VEDANTA LIMITED

# %%
output1.head(10)
# Out:
#   Date of Purchase       Purchaser Name Denomination Date of\nEncashment  \
# 0      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 1      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 2      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 3      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 4      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 5      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 6      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 7      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 8      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 9      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
#
#   Name of the Political Party
# 0        BHARTIYA JANTA PARTY
# 1        BHARTIYA JANTA PARTY
# 2        BHARTIYA JANTA PARTY
# 3        BHARTIYA JANTA PARTY
# ...

# %%
output1[output1['Purchaser Name'] == 'VEDANTA LIMITED']
# Out:
#           Date of Purchase   Purchaser Name Denomination Date of\nEncashment  \
# 431946         16/Apr/2019  VEDANTA LIMITED     1,00,000         12/Apr/2019
# 431947         16/Apr/2019  VEDANTA LIMITED     1,00,000         12/Apr/2019
# 431948         16/Apr/2019  VEDANTA LIMITED     1,00,000         12/Apr/2019
# 431949         16/Apr/2019  VEDANTA LIMITED     1,00,000         12/Apr/2019
# 431950         16/Apr/2019  VEDANTA LIMITED     1,00,000         12/Apr/2019
# ...                    ...              ...          ...                 ...
# 156858949      09/Nov/2023  VEDANTA LIMITED  1,00,00,000         24/Jan/2024
# 156858950      09/Nov/2023  VEDANTA LIMITED  1,00,00,000         24/Jan/2024
# 156858951      09/Nov/2023  VEDANTA LIMITED  1,00,00,000         24/Jan/2024
# 156858952      09/Nov/2023  VEDANTA LIMITED  1,00,00,000         24/Jan/2024
# 156858953      09/Nov/2023  VEDANTA LIMITED  1,00,00,000         24/Jan/2024
#
#           Name of the Political Party
# ...

# %%
#Find out all the Null Values in the data

# %% [markdown]
# output1.isnull().sum()

# %%
output1.isnull().sum()
# Out:
# Date of Purchase               0
# Purchaser Name                 0
# Denomination                   0
# Date of\nEncashment            0
# Name of the Political Party    0
# dtype: int64

# %%
output1.notnull().sum()
# Out:
# Date of Purchase               172948521
# Purchaser Name                 172948521
# Denomination                   172948521
# Date of\nEncashment            172948521
# Name of the Political Party    172948521
# dtype: int64

# %%
#Rename the column name 'Name of the Political Party' of the dataframe to 'Political Party'

# %% [markdown]
# output1.head(10)

# %%
output1.head(10)
# Out:
#   Date of Purchase       Purchaser Name Denomination Date of\nEncashment  \
# 0      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 1      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 2      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 3      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 4      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 5      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 6      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 7      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 8      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
# 9      12/Apr/2019  A B C INDIA LIMITED     1,00,000         12/Apr/2019
#
#   Name of the Political Party
# 0        BHARTIYA JANTA PARTY
# 1        BHARTIYA JANTA PARTY
# 2        BHARTIYA JANTA PARTY
# 3        BHARTIYA JANTA PARTY
# ...

# %%
output1.rename(columns = {'Name of the Political Party' : 'Political Party'},inplace = True)

# %%
output1
# Out:
#           Date of Purchase                      Purchaser Name Denomination  \
# 0              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 1              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 2              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 3              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 4              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# ...                    ...                                 ...          ...
# 172948516      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948517      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948518      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948519      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948520      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
#
# ...

# %%
#Find all the instances when the Denomination was above 1 lakh.

# %%
output1[output1['Denomination'] > '1,00,000']
# Out:
#           Date of Purchase                      Purchaser Name Denomination  \
# 5627928        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627929        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627930        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627931        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627932        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# ...                    ...                                 ...          ...
# 172948516      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948517      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948518      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948519      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948520      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
#
# ...

# %%
output1
# Out:
#           Date of Purchase                      Purchaser Name Denomination  \
# 0              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 1              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 2              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 3              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# 4              12/Apr/2019                 A B C INDIA LIMITED     1,00,000
# ...                    ...                                 ...          ...
# 172948516      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948517      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948518      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948519      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948520      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
#
# ...

# %%
#Find all the instances when the Denomination was above 1 lakh and political party was BHARTIYA JANTA PARTY.

# %%
output1[(output1['Denomination'] > '1,00,000') & (output1['Name of the Political Party'] == 'BHARTIYA JANTA PARTY')]
# Out:
#           Date of Purchase                      Purchaser Name Denomination  \
# 5627963        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627964        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627965        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627966        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627967        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# ...                    ...                                 ...          ...
# 172948456      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948457      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948458      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948459      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948520      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
#
# ...

# %%
output1[(output1['Denomination'] > '1,00,000') & (output1['Name of the Political Party'] == 'BHARTIYA JANTA PARTY')]
# Out:
#           Date of Purchase                      Purchaser Name Denomination  \
# 5627963        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627964        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627965        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627966        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# 5627967        12/Apr/2019                 A B C INDIA LIMITED    10,00,000
# ...                    ...                                 ...          ...
# 172948456      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948457      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948458      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948459      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
# 172948520      15/Nov/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO       10,000
#
# ...

# %%
#Finding the maximum Denomination.

# %%
output1.groupby('Denomination').max()
# Out:
#              Date of Purchase                      Purchaser Name  \
# Denomination
# 1,00,00,000       28/Oct/2020            ZYDUS HEALTHCARE LIMITED
# 1,00,000          28/Oct/2020                     YOGESH MANPURIA
# 1,000             23/Jan/2023   TRIBHUVAN SPINTEX PRIVATE LIMITED
# 10,00,000         28/Oct/2020             YOGESH MANNALAL AGRAWAL
# 10,000            21/Jan/2023  WARORA CHANDRAPUR BALLARPUR TOLLRO
#
#              Date of\nEncashment             Name of the Political Party
# Denomination
# 1,00,00,000          31/Oct/2020  YSR CONGRESS PARTY (YUVAJANA SRAMIKA R
# 1,00,000             31/Jan/2023  YSR CONGRESS PARTY (YUVAJANA SRAMIKA R
# 1,000                24/Jul/2023              SHIVSENA (POLITICAL PARTY)
# 10,00,000            31/Oct/2020  YSR CONGRESS PARTY (YUVAJANA SRAMIKA R
# 10,000               26/Apr/2023              SHIVSENA (POLITICAL PARTY)

# %%
#Finding the mean Denomination

# %%
output1.groupby('Denomination').min()
# Out:
#              Date of Purchase                  Purchaser Name  \
# Denomination
# 1,00,00,000       01/Jul/2022               14 REELS PLUS LLP
# 1,00,000          02/Apr/2022             A B C INDIA LIMITED
# 1,000             04/Jul/2022  ADWITA FINVEST PRIVATE LIMITED
# 10,00,000         01/Jul/2022             A B C INDIA LIMITED
# 10,000            03/Jan/2022                   ANAND AGARWAL
#
#              Date of\nEncashment   Name of the Political Party
# Denomination
# 1,00,00,000          01/Dec/2023               AAM AADMI PARTY
# 1,00,000             01/Feb/2023               AAM AADMI PARTY
# 1,000                12/Oct/2021  ALL INDIA TRINAMOOL CONGRESS
# 10,00,000            01/Dec/2023               AAM AADMI PARTY
# 10,000               06/Jan/2022  ALL INDIA TRINAMOOL CONGRESS

# %%
#Company that purchased minimum times the electoral bonds.

# %%
output1['Purchaser Name'].min()
# Out:
# '14 REELS PLUS LLP'

# %%
#Company that purchased maximum times the electoral bonds.

# %%
output1['Purchaser Name'].max()
# Out:
# 'ZYDUS HEALTHCARE LIMITED'

# %%
Parties = ['BJP','CONGRESS','TRINMUL CONGRESS','BRS','BJD','AAP']
Amount = [47.5,11.1,12.1,15,10,5]
fig = plt.figure(figsize =(10,7))
plt.pie(Amount,labels = Parties)
plt.show()

# %%
Amount = [47.5,11.1,12.1,15,10,5]
Amount = np.random.normal(47,11,12)
plt.hist(Amount);
plt.show()
plt.hist(Amount,bins = 30);
plt.show()

# %%
Y = [47,11,12,15,10,5]
X = ['BJP','CONGRESS','TMC','BRS','BDS','AAP',]
plt.bar(X,Y)
plt.title("Bar Graph")
plt.ylabel("PERCENTAGE OF BONDS RECEIVED")
plt.xlabel("PARTIES")
plt.show()
